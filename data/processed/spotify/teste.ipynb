# %%
import pandas as pd

# %%
df_artists = pd.read_csv("new_artists_enriched.csv")
df_albuns = pd.read_csv("new_albums_enriched.csv")
df_tracks = pd.read_csv("new_tracks_enriched.csv")

# %%
df_artists.head(10)
# Out:
#                             artist_mbid    artist_name  \
# 0                                   NaN          Adele
# 1  875203e1-8e58-4b86-8dcb-7190faf411c5        J. Cole
# 2                                   NaN          Drake
# 3  29e686ca-134e-46d5-8a5b-7193f618ff35         Sonder
# 4  b7539c32-53e7-4908-bda3-81449c367da6   Lana Del Rey
# 5                                   NaN        Pitbull
# 6  c8b03190-306c-4120-bb0b-6f2ebfc06ea9     The Weeknd
# 7  285e1285-aecc-478f-a8da-0c8cf69e1217         Miguel
# 8  b95ce3ff-3d05-4e87-9e01-c97b66af13d4         Eminem
# 9  e0140a67-e4d1-4f13-8a01-364355bee46e  Justin Bieber
#
#         artist_id_spotify                                         artist_url  \
# 0  3XPI2Rik4spEoO1VW3fHk7  https://open.spotify.com/artist/3XPI2Rik4spEoO...
# 1  6l3HvQ5sa6mXTsMTB19rO5  https://open.spotify.com/artist/6l3HvQ5sa6mXTs...
# 2  3TVXtAsR1Inumwj472S9r4  https://open.spotify.com/artist/3TVXtAsR1Inumw...
# ...

# %%
df_albuns.head(10)
# Out:
#                              album_mbid                          album_name  \
# 0  29f224ac-498d-4dcb-9a07-22b1293288ae                                  21
# 1  32ef7c3f-96bb-44a3-aa4d-7aa8c9640cf9             2014 Forest Hills Drive
# 2                                   NaN                  Take Care (Deluxe)
# 3  16a0fd7d-307d-4721-9c2b-ddb0d1d847d8                      What You Heard
# 4                                   NaN                   Snow On Tha Bluff
# 5  620e4932-cae3-49d0-9d87-a2685bd4c9c0                    4 Your Eyez Only
# 6  4e102cda-b8f6-4242-b4ae-ce2d16a5eac7                   Say Yes to Heaven
# 7                                   NaN  Born to Die - The Paradise Edition
# 8                                   NaN              Ultraviolence (Deluxe)
# 9  0c6272c4-f50a-4f80-a302-497038a7f5a0                 Young and Beautiful
#
#     artist_name                album_id album_type  total_tracks release_date  \
# ...

# %%
df_tracks.head(10)
# Out:
#                              track_mbid  \
# 0  0309071e-e8b6-4263-a68d-c4e4f8c4a988
# 1  f7f85d65-bd9d-4821-9d86-cc0d669bda6c
# 2                                   NaN
# 3  50acbb51-2ddb-451b-8e6e-acbe1dc9799a
# 4  ebb59e72-1549-438d-88e9-c27b697f9e90
# 5  64f84b86-2059-4a01-aab0-c7cd8e9aa341
# 6  47d724dd-ef88-4337-951e-a42647c21780
# 7  346c038a-1bd5-43f6-9bb5-b6e805e219b2
# 8  303a8f69-1196-47e2-82f6-9fcdd09cf09e
# 9  0d32af4f-5493-4f3b-a2ad-f61fa55698e6
#
#                                   track_name artist_name  \
# 0                                   Lovesong       Adele
# 1                                 Apparently     J. Cole
# 2  Cameras / Good Ones Go Interlude - Medley       Drake
# 3                             What You Heard      Sonder
# 4                          Snow On Tha Bluff     J. Cole
# 5                           4 Your Eyez Only     J. Cole
# 6                           She's Mine Pt. 2     J. Cole
# ...
